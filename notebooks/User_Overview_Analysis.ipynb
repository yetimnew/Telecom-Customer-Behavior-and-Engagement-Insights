# %%
import sys
import os
import matplotlib.pyplot as plt

project_path = r"D:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights"
if project_path not in sys.path:
    sys.path.append(project_path)

# %%
from scripts import TelecomAnalysis

# %%
database = "telecom"
password = "password"
table_name = "xdr_data"

analysis = TelecomAnalysis(database=database, password=password, table_name=table_name)

# Step 1: Load the data
data = analysis.load_data()

# Step 2: Explore the dataset
# analysis.explore_data()
# Out:
# Data loaded successfully!

# %% [markdown]
# ## Find the top 10 handsets

# %%
# Step 3: Find the top 10 handsets
top_handsets = analysis.find_top_handsets()
print("\nTop 10 Handsets:")
print(top_handsets)
# Out:
# Top 10 Handsets:
#  Handset Type
# Huawei B528S-23A                79008
# Apple iPhone 6S (A1688)         37676
# Apple iPhone 6 (A1586)          36092
# undefined                       35948
# Apple iPhone 7 (A1778)          25304
# Apple iPhone Se (A1723)         20748
# Apple iPhone 8 (A1905)          19972
# Apple iPhone Xr (A2105)         18272
# Samsung Galaxy S8 (Sm-G950F)    18080
# Apple iPhone X (A1901)          15252
# Name: count, dtype: int64
#
# Top 10 Handsets:
# Handset Type
# Huawei B528S-23A                79008
# Apple iPhone 6S (A1688)         37676
# Apple iPhone 6 (A1586)          36092
# undefined                       35948
# Apple iPhone 7 (A1778)          25304
# Apple iPhone Se (A1723)         20748
# Apple iPhone 8 (A1905)          19972
# Apple iPhone Xr (A2105)         18272
# Samsung Galaxy S8 (Sm-G950F)    18080
# Apple iPhone X (A1901)          15252
# Name: count, dtype: int64

# %%
# Plot the Top 10 Handsets
if top_handsets is not None:
    plt.figure(figsize=(18, 6))
    top_handsets.plot(kind='bar', color='skyblue')
    plt.title('Top 10 Handsets Used by Customers', fontsize=16)
    plt.xlabel('Handset Type', fontsize=14)
    plt.ylabel('Number of Users', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
else:
    print("No data available for plotting.")

# %% [markdown]
# ## Find the top 3 handset manufacturers

# %%
# Step 4: Find the top 3 handset manufacturers
top_manufacturers = analysis.find_top_manufacturers()
print("\nTop 3 Handset Manufacturers:")
print(top_manufacturers)
# Out:
# Top 3 Handset Manufacturers:
#  Handset Manufacturer
# Apple      238260
# Samsung    163356
# Huawei     137692
# Name: count, dtype: int64
#
# Top 3 Handset Manufacturers:
# Handset Manufacturer
# Apple      238260
# Samsung    163356
# Huawei     137692
# Name: count, dtype: int64

# %%
# Plot the Top 3 Handset Manufacturers
if top_manufacturers is not None:
    import matplotlib.pyplot as plt

    plt.figure(figsize=(8, 5))
    top_manufacturers.plot(kind='bar', color='orange')
    plt.title('Top 3 Handset Manufacturers', fontsize=16)
    plt.xlabel('Manufacturer', fontsize=14)
    plt.ylabel('Number of Users', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
else:
    print("No data available for plotting.")

# %% [markdown]
# ss

# %%
# Step 5: Find the top 5 handsets for each of the top 3 handset manufacturers
if top_manufacturers is not None:
    # Extract the manufacturer names from the index of the Series
    manufacturers_list = top_manufacturers.index.tolist()
    top_handsets_per_manufacturer = analysis.find_top_handsets_per_manufacturer(manufacturers=manufacturers_list, n=5)
    print("\nTop 5 Handsets for Each Top Manufacturer:")
    for manufacturer, handsets in top_handsets_per_manufacturer.items():
        print(f"\nManufacturer: {manufacturer}")
        print(handsets)
else:
    print("Could not retrieve top handset manufacturers.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Step 5: Find the top 5 handsets for each of the top 3 handset manufacturers
#       2 if top_manufacturers is not None:
# ----> 3     top_handsets_per_manufacturer = analysis.find_top_handsets_per_manufacturer(n=5)
#       4     print("\nTop 5 Handsets for Each Top Manufacturer:")
#       5     for manufacturer, handsets in top_handsets_per_manufacturer.items():
#
# TypeError: TelecomAnalysis.find_top_handsets_per_manufacturer() missing 1 required positional argument: 'manufacturers'

# %%
analysis.find_top_handsets_per_manufacturer(n=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 analysis.find_top_handsets_per_manufacturer(n=5)
#
# TypeError: TelecomAnalysis.find_top_handsets_per_manufacturer() missing 1 required positional argument: 'manufacturers'

# %%
# Step 5: Plot the Top 10 Handsets
if top_handsets is not None:
    plt.figure(figsize=(18, 6))
    top_handsets.plot(kind='bar', color='skyblue')
    plt.title('Top 10 Handsets Used by Customers', fontsize=16)
    plt.xlabel('Handset Type', fontsize=14)
    plt.ylabel('Number of Users', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
else:
    print("No data available for plotting.")

# %%
# Step 6: Aggregate user metrics
user_metrics = analysis.aggregate_user_metrics()
print("\nAggregated User Metrics:")
print(user_metrics.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Step 6: Aggregate user metrics
# ----> 2 user_metrics = analysis.aggregate_user_metrics()
#       3 print("\nAggregated User Metrics:")
#       4 print(user_metrics.head())
#
# File D:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\scripts\telecom_analysis.py:95, in TelecomAnalysis.aggregate_user_metrics(self)
#      92 if self.data is not None:
#      93     # Use the exact column names from the dataset
#      94     if 'MSISDN/Number' in self.data.columns:
# ---> 95         user_metrics = self.data.groupby('MSISDN/Number').agg(
#      96             total_sessions=('bearer id', 'count'),  # Ensure 'bearer id' exists
#      97             total_download=('Total DL (Bytes)', 'sum'),  # Ensure 'Total DL (Bytes)' exists
#      98             total_upload=('Total UL (Bytes)', 'sum'),  # Ensure 'Total UL (Bytes)' exists
#      99             total_data_volume=('Total DL (Bytes)', 'sum'),  # Same as total_download
#     100             average_duration=('Dur. (s)', 'mean')  # Ensure 'Dur. (s)' exists
#     101         )
#     102         print("\nAggregated User Metrics:")
#     103         print(user_metrics.head())
#
# File d:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\.env\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File d:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\.env\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File d:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\.env\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)
#     421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File d:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\.env\Lib\site-packages\pandas\core\apply.py:1608, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1603     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1605 with com.temp_setattr(
#    1606     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607 ):
# -> 1608     result_index, result_data = self.compute_dict_like(
#    1609         op_name, selected_obj, selection, kwargs
#    1610     )
#    1611 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1612 return result
#
# File d:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\.env\Lib\site-packages\pandas\core\apply.py:462, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461 func = cast(AggFuncTypeDict, self.func)
# --> 462 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     464 is_non_unique_col = (
#     465     selected_obj.ndim == 2
#     466     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     467 )
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#
# File d:\10x\Projects\Telecom-Customer-Behavior-and-Engagement-Insights\.env\Lib\site-packages\pandas\core\apply.py:663, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     661     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662     if len(cols) > 0:
# --> 663         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     665 aggregator_types = (list, tuple, dict)
#     667 # if we have a dict of any non-scalars
#     668 # eg. {'A' : ['mean']}, normalize all to
#     669 # be list-likes
#     670 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Dur. (s)', 'bearer id'] do not exist"
